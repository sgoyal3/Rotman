# %%
import requests
import pandas as pd
import numpy as np
API_KEY = {'X-API-key': 'LBFAK2UH'}
port = "9999"


#submit orders
# http://localhost:8080/v1/orders&ticker=CRZY&type=MARKET&quantity=100
#&action=BUY, where &ticker=CRZY&type=MARKET&quantity=100&action=BUY
with requests.Session() as s:
    s.headers.update(API_KEY)

# %%
def get_time_remaining():
    s.headers.update(API_KEY)
    resp = s.get('http://localhost:{}/v1/case'.format(port))
    if resp.status_code == 200:
        case = resp.json()
        tick = case['tick']
        return 300 - tick
    return 0

def get_tick(self):
    s.headers.update(API_KEY)
    resp = s.get('http://localhost:{}/v1/case'.format(port))
    if resp.status_code == 200:
        case = resp.json()
        tick = case['tick']
        return tick

def get_tender_info():
    s.headers.update(API_KEY)
    resp = s.get('http://localhost:{}/v1/tenders'.format(port))
    if resp.status_code == 200:
        tender = resp.json()
        if len(tender) > 0:
            return tender[0]['tender_id'], tender[0]['quantity'], tender[0]['action'], tender[0]['price']
    return

def get_bid_and_ask(ticker):
    s.headers.update(API_KEY)
    resp = s.get('http://localhost:{}/v1/securities/book?ticker={}&limit=1'.format(port, ticker))
    if resp.status_code == 200:
        order = resp.json()
        return order['bids'][0]['price'], order['bids'][0]['quantity'], order['asks'][0]['price'], order['asks'][0]['quantity']
    return

def add_market_order(ticker, vol, sell):
    s.headers.update(API_KEY)
    if sell:
        action = 'SELL'
    else:
        action = 'BUY'
    params = {'ticker': ticker, 'type': 'MARKET', 'quantity': vol, 'action': action}
    resp = s.post('http://localhost:{}/v1/orders'.format(port), params= params)
    if resp.status_code == 200:
        print("Successfully submitted market order")
    return

def add_limit_order(ticker, vol, price, sell):
    if sell:
        action = 'SELL'
    else:
        action = 'BUY'
    params = {'ticker': ticker, 'type': 'LIMIT', 'quantity': vol,
              'action': action, 'price': price}
    resp = s.post('http://localhost:{}/v1/orders'.format(port), params= params)
    if resp.status_code == 200:
        print("Added limit order to ", action, " ", vol, " ", ticker)
    return

def vol_imbalance(bid_vol, ask_vol):
    return (bid_vol - ask_vol)/(bid_vol + ask_vol)

def flow_imbalance(bid_vol, ask_vol, lag_bid_vol, lag_ask_vol, bid_price, ask_price, lag_bid_price, lag_ask_price):
    if bid_price < lag_bid_price:
        deltaB = 0
    elif bid_price == lag_bid_price:
        deltaB = bid_vol - lag_bid_vol
    else:
        deltaB = bid_vol
    if ask_price < lag_ask_price:
        deltaA = ask_vol
    elif ask_price == lag_ask_price:
        deltaA = ask_vol - lag_ask_vol
    else:
        deltaA = 0
    return deltaB - deltaA

def get_ticker_info(ticker, info):
    resp = s.get('http://localhost:{}/v1/securities?ticker={}'.format(port, ticker))
    if resp.status_code == 200:
        security = resp.json()
        if info == 'position':
            return security[0]['position']
    return 0

def market_unload(ticker, volume):
    if volume > 0:
        while volume > 10000:
            add_market_order(ticker, 10000,sell = True)
            volume = volume - 10000
        add_market_order(ticker, volume, sell = True)
    else:
        while volume < -10000:
            add_market_order(ticker, 10000, sell = False)
            volume = volume + 10000
        add_market_order(ticker, (-1)*volume, sell = False)
    return

def tender_accept():
    tender = get_tender_info()
    if tender:
        resp = s.post('http://localhost:{}/v1/tenders/{}'.format(port, str(tender[0])))
        if resp.status_code == 200:
            print("accepted tender!")
    return

# %%
s.headers.update(API_KEY)
resp = s.get('http://localhost:{}/v1/securities/book?ticker='.format(port) + "RITC" + '&limit=1')
if resp.ok:
    order = resp.json()

# %%
resp.json()
# Out:
# {u'asks': [], u'bids': []}

# %%
resp.status_code
# Out:
# 200

# %%
get_tender_info()

# %%
add_market_order("RITC", 5000, "BUY")
# Out:
# Successfully submitted market order

# %%
add_limit_order("RITC", 5000, 18.0, "BUY")
# Out:
# ('Added limit order to ', 'SELL', ' ', 5000, ' ', 'RITC')

# %%
resp = s.get('http://localhost:{}/v1/securities/book?ticker=RITC&limit=5'.format(port))
if resp.status_code == 200:
    order = resp.json()
order
# Out:
# {u'asks': [{u'action': u'SELL',
#    u'order_id': 2824,
#    u'period': 1,
#    u'price': 24.87,
#    u'quantity': 11500.0,
#    u'quantity_filled': 0.0,
#    u'status': u'OPEN',
#    u'tick': 272,
#    u'ticker': u'RITC',
#    u'trader_id': u'ANON',
#    u'type': u'LIMIT',
#    u'vwap': None},
#   {u'action': u'SELL',
#    u'order_id': 2857,
#    u'period': 1,
#    u'price': 24.87,
#    u'quantity': 10000.0,
#    u'quantity_filled': 0.0,
#    u'status': u'OPEN',
#    u'tick': 276,
#    u'ticker': u'RITC',
#    u'trader_id': u'besttrader',
#    u'type': u'LIMIT',
#    u'vwap': None},
#   {u'action': u'SELL',
#    u'order_id': 2859,
#    u'period': 1,
#    u'price': 24.87,
#    u'quantity': 10000.0,
#    u'quantity_filled': 0.0,
#    u'status': u'OPEN',
#    u'tick': 276,
#    u'ticker': u'RITC',
#    u'trader_id': u'besttrader',
#    u'type': u'LIMIT',
#    u'vwap': None},
#   {u'action': u'SELL',
#    u'order_id': 2865,
#    u'period': 1,
#    u'price': 24.87,
#    u'quantity': 10000.0,
#    u'quantity_filled': 0.0,
#    u'status': u'OPEN',
#    u'tick': 276,
#    u'ticker': u'RITC',
#    u'trader_id': u'besttrader',
#    u'type': u'LIMIT',
#    u'vwap': None},
#   {u'action': u'SELL',
#    u'order_id': 2845,
#    u'period': 1,
#    u'price': 24.93,
#    u'quantity': 9500.0,
#    u'quantity_filled': 0.0,
#    u'status': u'OPEN',
#    u'tick': 274,
#    u'ticker': u'RITC',
#    u'trader_id': u'ANON',
#    u'type': u'LIMIT',
#    u'vwap': None}],
#  u'bids': [{u'action': u'BUY',
#    u'order_id': 2498,
#    u'period': 1,
#    u'price': 24.81,
#    u'quantity': 9800.0,
#    u'quantity_filled': 5000.0,
#    u'status': u'OPEN',
#    u'tick': 242,
#    u'ticker': u'RITC',
#    u'trader_id': u'ANON',
#    u'type': u'LIMIT',
#    u'vwap': 24.81},
#   {u'action': u'BUY',
#    u'order_id': 2533,
#    u'period': 1,
#    u'price': 24.8,
#    u'quantity': 8900.0,
#    u'quantity_filled': 0.0,
#    u'status': u'OPEN',
#    u'tick': 246,
#    u'ticker': u'RITC',
#    u'trader_id': u'ANON',
#    u'type': u'LIMIT',
#    u'vwap': None},
#   {u'action': u'BUY',
#    u'order_id': 2409,
#    u'period': 1,
#    u'price': 24.79,
#    u'quantity': 9600.0,
#    u'quantity_filled': 1600.0,
#    u'status': u'OPEN',
#    u'tick': 232,
#    u'ticker': u'RITC',
#    u'trader_id': u'ANON',
#    u'type': u'LIMIT',
#    u'vwap': 24.79},
#   {u'action': u'BUY',
#    u'order_id': 2444,
#    u'period': 1,
#    u'price': 24.79,
#    u'quantity': 11700.0,
#    u'quantity_filled': 0.0,
#    u'status': u'OPEN',
#    u'tick': 236,
#    u'ticker': u'RITC',
#    u'trader_id': u'ANON',
#    u'type': u'LIMIT',
#    u'vwap': None},
#   {u'action': u'BUY',
#    u'order_id': 2126,
#    u'period': 1,
#    u'price': 24.74,
#    u'quantity': 11900.0,
#    u'quantity_filled': 3000.0,
#    u'status': u'OPEN',
#    u'tick': 204,
#    u'ticker': u'RITC',
#    u'trader_id': u'ANON',
#    u'type': u'LIMIT',
#    u'vwap': 24.74}]}

# %%
params = {'ticker': "RITC", 'type': 'LIMIT', 'quantity': 10000, 'price': 22, 'action': "BUY"}
resp = s.post('http://localhost:{}/v1/orders'.format(port), params= params)

# %%
resp = s.get('http://localhost:{}/v1/orders?status=OPEN'.format(port))
resp.status_code, resp.json()
# Out:
# (200, [])

# %%
resp = s.get('http://localhost:{}/v1/securities?ticker=RITC'.format(port))
resp.status_code, resp.json()
# Out:
# (200,
#  [{u'ask': 25.99,
#    u'ask_size': 22300.0,
#    u'bid': 25.95,
#    u'bid_size': 3400.0,
#    u'currency': u'USD',
#    u'interest_rate': 0.0,
#    u'is_shortable': True,
#    u'is_tradeable': True,
#    u'last': 25.99,
#    u'limits': [{u'name': u'LIMIT-STOCK', u'units': 0.5}],
#    u'nlv': 0.0,
#    u'position': 0.0,
#    u'realized': 0.0,
#    u'size': 1,
#    u'start_period': 1,
#    u'stop_period': 1,
#    u'ticker': u'RITC',
#    u'total_volume': 1121000.0,
#    u'type': u'STOCK',
#    u'unrealized': 0.0,
#    u'volume': 1121000.0,
#    u'vwap': 0.0}])

# %%
class AggOrder:
    def __init__(self, order_json, marketOrder=True):
        self.init = False
        self.price = None
        self.action = None
        self.type = None
        self.volume_unfilled = self.volume_filled = None
        self.id = None
        # indicate whether this is order object in market book
        self.marketOrder=marketOrder
        if marketOrder:
            self.aggregate_market(order_json)
        else:
            self.aggregate_trader(order_json)
        
    def __repr__(self):
        output = "" if self.marketOrder else "id: {} ".format(self.id)
        output += "Order({}, {}, price: {}, volume_unfilled: {})".format(
            self.action, self.type, self.price, self.volume_unfilled)
        return output
        
    def aggregate_market(self, order_json):
        # need to aggregate
        if self.init == False:
            self.init = True
            self.price = order_json["price"]
            self.type = order_json["type"]
            self.action = order_json["action"]
            self.volume_filled = order_json["quantity_filled"]
            self.volume_unfilled = order_json["quantity"] - order_json["quantity_filled"]
        else:
            self.volume_filled += order_json["quantity_filled"]
            self.volume_unfilled += (order_json["quantity"] - order_json["quantity_filled"])
   
    # don't have to call this for trader book
    def aggregate_trader(self, order_json):
        if self.init == False:
            self.init = True
            self.id = [order_json["order_id"]]
            self.price = order_json["price"]
            self.type = order_json["type"]
            self.action = order_json["action"]
            self.volume_filled = order_json["quantity_filled"]
            self.volume_unfilled = order_json["quantity"] - order_json["quantity_filled"]
        else:
            self.id.append(order_json["order_id"])
            self.volume_filled += order_json["quantity_filled"]
            self.volume_unfilled += (order_json["quantity"] - order_json["quantity_filled"])
            

class OrderBook:
    def __init__(self, session, size=5):
        self.s = session
        self.size = size
        # limit of queries to send
        self.record_limit = 3 * size
        self.marketBookSize = size
        self.tickers = ["BULL", "BEAR", "RITC"]
        self.actions = ["bids", "asks"]
        
        # current and lag order book
        self.marketBook = self.create_new_book()
        self.traderBook = self.create_new_book()
        self.lag_marketBook = self.create_new_book()

            
    def create_new_book(self):
        output = dict.fromkeys(self.tickers)
        for k in self.tickers:
            output[k] = dict.fromkeys(self.actions)
        return output
            
    # market orders are arranged in price (logically reasonable for Bid and Ask)
    # this only updates order info for the specified ticker!
    def updateMarketBook(self, ticker):
        if ticker not in self.tickers:
            print("Check Ticker!")
            return
        resp = s.get('http://localhost:{}/v1/securities/book?ticker={}&limit={}'.format(
            port, ticker, self.record_limit))
        if resp.status_code == 200:
            # update lag_order book and clear out prev records
            self.lag_marketBook[ticker] = self.marketBook[ticker]
            self.marketBook[ticker] = dict.fromkeys(self.actions)
            
            content = resp.json()   
            for order_type in self.actions:
                if len(content[order_type]) == 0:
                    continue
                # maintain a list of length self.size
                self.marketBook[ticker][order_type] = []
                prev_price = None
                
                # price we maintain in order book
                price_arr = list(dict.fromkeys([item["price"] for item in content[order_type]]))[:self.size]
                bchmk_price = price_arr[-1]
                
                for order in content[order_type]:
                    if order['action'] == "BUY" and order['price'] < bchmk_price or \
                        order['action'] == "SELL" and order['price'] > bchmk_price:
                        break
                        
                    if order['price'] != prev_price:
                        prev_price = order['price']
                        self.marketBook[ticker][order_type].append(AggOrder(order))
                    else:
                        self.marketBook[ticker][order_type][-1].aggregate_market(order)
        else:
            print(resp.json())

            
    def updateAllMarketBook(self):
        for k in self.tickers:
            self.updateMarketBook(k)
            
    # Trader Book can be arraged in differnt orders!
    # if order by time, then in descending order of time that orders stayed open
    # if order by price, then in logical order of price (bid vs ask)
    def updateTraderBook(self, ticker, orderBy="time", aggregate=False):
        if ticker not in self.tickers:
            print("Check Ticker!")
            return
        resp = s.get('http://localhost:{}/v1/orders?status=OPEN'.format(port))

        if resp.status_code == 200:        
            # clear out prev records
            self.traderBook[ticker] = dict.fromkeys(self.actions)
            self.traderBook[ticker]["bids"] = []
            self.traderBook[ticker]["asks"] = []
            content = resp.json()
            if len(content) == 0:
                return
            # keep track of individual open order
            if not aggregate:
                for order in content:
                    if order['action'] == "BUY":
                        self.traderBook[order["ticker"]]["bids"].append(AggOrder(order, marketOrder=False))
                    else:
                        self.traderBook[order["ticker"]]["asks"].append(AggOrder(order, marketOrder=False))
            else:
                prev_price = None
                for order in content:
                    if order['price'] != prev_price:
                        prev_price = order['price']
                        self.traderBook[ticker][order_type].append(AggOrder(order, marketOrder=False))
                    else:
                        self.traderBook[ticker][order_type][-1].aggregate_trader(order)
            
            if orderBy == "price":
                self.traderBook[ticker]["bids"].sort(key=lambda x: -x.price)
                self.traderBook[ticker]["asks"].sort(key=lambda x: x.price)
  
        else:
            print(resp.json())
            
    def get_market_volume_and_vwap(self, ticker):
        vwap_bid = vwap_ask = 0.0
        volume_bid = volume_ask = 0.0
        
        for order in self.marketBook[ticker]["bids"]:
            vwap_bid += order.volume_unfilled * order.price
            volume_bid += order.volume_unfilled
        vwap_bid /= volume_bid

        for order in self.marketBook[ticker]["asks"]:
            vwap_ask += order.volume_unfilled * order.price
            volume_ask += order.volume_unfilled
        vwap_ask /= volume_ask
        
        return volume_bid, volume_ask, vwap_bid, vwap_ask
           
    def print_market_book(self, ticker):
        print("Bid: {}".format(self.marketBook[ticker]["bids"]))
        print("Ask: {}".format(self.marketBook[ticker]["asks"]))
    
    def print_trader_book(self, ticker):
        print("Bid: {}".format(self.traderBook[ticker]["bids"]))
        print("Ask: {}".format(self.traderBook[ticker]["asks"]))
        
    
    def check_data_available(self, ticker):
        try:
            curr_avail = len(self.marketBook[ticker]["bids"]) and len(self.marketBook[ticker]["asks"])
            lag_avail = len(self.lag_marketBook[ticker]["bids"]) and len(self.lag_marketBook[ticker]["asks"])
        except TypeError:
            return False, False
        return bool(lag_avail), bool(curr_avail)
        
        
    # Stats for Spread:
    def get_bid_ask(self, ticker):
        return self.marketBook[ticker]["bids"][0].price, self.marketBook[ticker]["asks"][0].price
    
    def get_bid_ask_spread(self, ticker):
        return self.marketBook[ticker]["asks"][0].price - self.marketBook[ticker]["bids"][0].price
        
    def get_mid_price(self, ticker, vwap=False):
        if not vwap:
            return (self.marketBook[ticker]["asks"][0].price + self.marketBook[ticker]["bids"][0].price) / 2.0
        else:
            _, _, vwap_bid, vwap_ask = self.get_market_volume_and_vwap(ticker)
            return (vwap_bid + vwap_ask) / 2.0

    
    # if use vwap = False, then just the best bid/ask price
    def get_vol_imbalance(self, ticker, vwap=False):
        if not vwap:
            bid_vol = self.marketBook[ticker]["bids"][0].volume_unfilled
            ask_vol = self.marketBook[ticker]["asks"][0].volume_unfilled
        else:
            bid_vol, ask_vol, _, _ = self.get_market_volume_and_vwap(ticker)

        return (bid_vol - ask_vol) / (bid_vol + ask_vol)
        
    
    def get_flow_imbalance(self, ticker):
        best_bid = self.marketBook[ticker]["bids"][0]
        best_ask = self.marketBook[ticker]["asks"][0]
        lag_best_bid = self.lag_marketBook[ticker]["bids"][0]
        lag_best_ask = self.lag_marketBook[ticker]["asks"][0]
        deltaA = deltaB = None

        if best_bid.price < lag_best_bid.price:
            deltaB = 0
        elif best_bid.price == lag_best_bid.price:
            deltaB = best_bid.volume_unfilled - lag_best_bid.volume_unfilled
        else:
            deltaB = best_bid.volume_unfilled

        if best_ask.price < lag_best_ask.price:
            deltaA = best_ask.volume_unfilled
        elif best_ask.price == lag_best_ask.price:
            deltaA = best_ask.volume_unfilled < lag_best_ask.volume_unfilled
        else:
            deltaA = 0
        return deltaB - deltaA
    
    # trading api
    def cancel_bad_orders(self, ticker, action, spread_threshold = 0.0):
        try:
            cancel_ids = []
            best_price = self.marketBook[ticker][action][0].price
            for order in self.traderBook[ticker][action]:
                if (action=="bids" and best_price - order.price <= spread_threshold) or \
                    (action=="asks" and order.price - best_price <= spread_threshold):
                        cancel_ids.extend(order.id)
            if len(cancel_ids):
                cancel_ids = [str(id) for id in cancel_ids]
                resp = s.post('http://localhost:{}/v1/commands/cancel?ids={}'.format(port, ','.join(cancel_ids)))
                if resp.status_code == 200:
                    print("Canceled orders: {}".format(cancel_ids))
                        
        except TypeError:
            return

# %%
# Out:
# 'a'

# %%
myOrderBook = OrderBook(s, size=5)

# %%
myOrderBook.updateMarketBook("RITC")
myOrderBook.updateTraderBook("RITC", orderBy="price")
myOrderBook.print_trader_book("RITC")
myOrderBook.print_market_book("RITC")
myOrderBook.check_data_available("RITC")
# Out:
# Bid: []
# Ask: []
# Bid: [Order(BUY, LIMIT, price: 24.6, volume_unfilled: 10000.0), Order(BUY, LIMIT, price: 24.46, volume_unfilled: 9200.0), Order(BUY, LIMIT, price: 24.39, volume_unfilled: 10500.0), Order(BUY, LIMIT, price: 24.34, volume_unfilled: 11400.0), Order(BUY, LIMIT, price: 24.2, volume_unfilled: 10700.0), Order(BUY, LIMIT, price: 24.06, volume_unfilled: 9900.0), Order(BUY, LIMIT, price: 24.04, volume_unfilled: 8900.0), Order(BUY, LIMIT, price: 24.03, volume_unfilled: 11900.0), Order(BUY, LIMIT, price: 24.02, volume_unfilled: 11700.0), Order(BUY, LIMIT, price: 23.91, volume_unfilled: 19300.0), Order(BUY, LIMIT, price: 23.9, volume_unfilled: 10500.0), Order(BUY, LIMIT, price: 23.62, volume_unfilled: 9200.0)]
# Ask: [Order(SELL, LIMIT, price: 24.61, volume_unfilled: 3300.0), Order(SELL, LIMIT, price: 24.85, volume_unfilled: 5400.0), Order(SELL, LIMIT, price: 24.89, volume_unfilled: 1100.0)]
# (True, True)

# %%
add_limit_order('RITC', 200, 20, None)
myOrderBook.updateTraderBook("RITC", orderBy="price")
myOrderBook.print_trader_book("RITC")
# Out:
# ('Added limit order to ', 'BUY', ' ', 200, ' ', 'RITC')
# Bid: [id: [534] Order(BUY, LIMIT, price: 20.0, volume_unfilled: 200.0), id: [513] Order(BUY, LIMIT, price: 20.0, volume_unfilled: 200.0), id: [484] Order(BUY, LIMIT, price: 20.0, volume_unfilled: 200.0)]
# Ask: []

# %%
class TenderManager:
    def __init__(self, session, wait_tick=5):
        # this also indicates whether have pending offer
        self.last_tick_took = None
        self.s = session
        self.wait_tick = wait_tick
        self.last_tender_info = None
        
        
    def handle_offer(self, orderBook):            
        # handle new offers    
        if self.last_tick_took is None:
            resp = s.get('http://localhost:{}/v1/tenders'.format(port))
            if resp.status_code == 200:
                tender = resp.json()
                if len(tender) > 0:
                    self.last_tick_took = self.get_tick()
                    tender_id = tender[0]['tender_id']
                    quantity = tender[0]['quantity']
                    action = tender[0]['action']
                    price = tender[0]['price']                    
                    self.last_tender_info = [tender_id, action, price, quantity]
                    
        # handle offers on hand, real logic here
        if self.last_tick_took is not None and self.get_tick() - self.last_tick_took <= self.wait_tick:
            tender_id, action, price, quantity = *self.last_tender_info
            current_bid, current_ask = orderBook.get_bid_ask("RITC")
            bid_vol, ask_vol, bid_vwap, ask_vwap = orderBook.get_market_and_volume("RITC")
            
            if action == 'BUY' and p < current_bid - 0.1 and p < bid_vwap - 0.05:
                # submit orders on the opposite side
                
                
                resp = s.post('http://localhost:9999/v1/tenders/' + str(tender[0]))
                if resp.ok:
                    print("accepted tender!")
                return p
            if a == 'SELL' and p > current_ask+0.15:
                resp = s.post('http://localhost:9999/v1/tenders/' + str(tender[0]))
                if resp.ok:
                    print("accepted tender!")   
                return p

            
            
            resp = s.post('http://localhost:9999/v1/tenders/' + str(tender[0]))
            if resp.ok:
                self.last_tick_took = None
                self.last_tender_info
                print("accepted tender: {}, price: {}, quantity: {}!".format(action, price, quantity))



                        
    def

# %%
get_time_remaining()
# Out:
# 300

# %%
def main():
    myOrderBook = OrderBook(s, size=5)
    
    while get_time_remaining() > 1:
        
        myOrderBook.updateAllMarketBook()
        myOrderBook.updateTraderBook("RITC", orderBy="price")
        
        lag_data_avail, curr_data_avail = myOrderBook.check_data_available("RITC")
        
        VB = FB = 0
        
        if curr_data_avail:
            VB = myOrderBook.get_vol_imbalance("RITC")
            if lag_data_avail:
                FB = myOrderBook.get_flow_imbalance("RITC")
        
        current_bid, current_ask = myOrderBook.get_bid_ask("RITC")

        if VB > 0.3:
            add_limit_order('RITC', 1000, current_bid+0.01, None)
            myOrderBook.cancel_bad_orders("RITC", "asks", spread_threshold=0.01)
            add_limit_order('RITC', 1000, current_ask, 1)
        if VB < -0.3:
            add_limit_order('RITC', 1000, current_ask-0.01, 1)
            myOrderBook.cancel_bad_orders("RITC", "bids", spread_threshold=0.01)
            add_limit_order('RITC', 1000, current_bid, None)

        myOrderBook.updateTraderBook("RITC", orderBy="price")

        if FB > 5000:
            add_limit_order('RITC', 1000, current_bid+0.01, None)
            myOrderBook.cancel_bad_orders("RITC", "asks", spread_threshold=0.01)
            add_limit_order('RITC', 1000, current_ask, 1)

        if FB < -5000:
            add_limit_order('RITC', 1000, current_ask-0.01, 1)
            myOrderBook.cancel_bad_orders("RITC", "bids", spread_threshold=0.01)
            add_limit_order('RITC', 1000, current_bid, None)

        if np.random.uniform(0,1,1) > 0.8:
            resp = s.post('http://localhost:{}/v1/commands/cancel?all=1'.format(port))
        
        
        
        
        position = get_ticker_info('RITC', 'position')
        
        if current_ask - current_bid > 0.04:
            add_limit_order('RITC', 500, current_bid, None)
            add_limit_order('RITC', 500, current_bid-0.01, None)
            add_limit_order('RITC', 500, current_bid-0.02, None)
            add_limit_order('RITC', 500, current_ask-0.01, 1)
            add_limit_order('RITC', 500, current_ask, 1)
            add_limit_order('RITC', 500, current_ask+0.01, 1)
            add_limit_order('RITC', 500, current_ask+0.02, 1)
        
        if position <= -1000:
            add_limit_order('RITC', 1000, current_bid+0.01, None)
            add_limit_order('RITC', 1000, current_bid, None)
            add_limit_order('RITC', 1000, current_bid-0.01, None)
            add_limit_order('RITC', 1000, current_bid-0.02, None)
            add_limit_order('RITC', 1000, current_bid-0.03, None)
            add_limit_order('RITC', 1000, current_bid-0.04, None)
        
        if position >= 1000:
            add_limit_order('RITC', 1000, current_ask-0.01, 1)
            add_limit_order('RITC', 1000, current_ask, 1)
            add_limit_order('RITC', 1000, current_ask+0.01, 1)
            add_limit_order('RITC', 1000, current_ask+0.02, 1)
            add_limit_order('RITC', 1000, current_ask+0.03, 1)
            add_limit_order('RITC', 1000, current_ask+0.04, 1)

            
if __name__ == '__main__':
    main()
# Out:
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['1435', '1436']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['1435', '1436']
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['1494', '1490']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['1515']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['1515']
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['1515']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['1522', '1513']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['1571']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['1571']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['1628', '1624']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['1628', '1624']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['1672', '1669', '1665', '1660']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['1672', '1669', '1665', '1660']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['1688']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['1688', '1694']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['1688', '1694']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['1714']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['1714']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['1751']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['1751']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['1795', '1775', '1769']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['1813', '1806']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['1813', '1806']
# Canceled orders: ['1813', '1806']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['1819']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['1819']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['1848']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['1848']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['1984']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['1984']
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2013']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2013']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2028']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2036']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2036']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2036']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2060']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2060']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2078']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2078']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['2103', '2101']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2109']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2109']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2117', '2115', '2112']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2121']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2121']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2158']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2177']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2177']
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2186']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2186']
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2212']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['2222']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['2255', '2251']
# Canceled orders: ['2255', '2251']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2266']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['2266']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['2298']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2298']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2298']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2301', '2293']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2301', '2293']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2316']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2316']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2345']
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['2345']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2423']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['2423']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2423']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['2442']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2442']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['2452']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2548']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2551']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2575']
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['2575']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2602']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2620']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['2620']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['2630', '2631', '2623']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2630', '2631', '2623']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2653']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['2671']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['2720']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2720']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2720']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2744', '2742']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2853', '2841']
# Canceled orders: ['2853', '2841']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2853', '2841']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2858']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2858']
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2896', '2886']
# Canceled orders: ['2896', '2886']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['2944', '2940', '2924', '2919']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2958', '2954']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['2958', '2954']
# Canceled orders: ['2958', '2954']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3022']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3022']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3022']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3028', '3031']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3028', '3031']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3037', '3035']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3062']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3062']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3066', '3064']
# Canceled orders: ['3066', '3064']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3098']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3098']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3106']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3106']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3111', '3110', '3108']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3118']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['3118']
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3125']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['3125']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3141']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3153']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3153']
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['3153']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['3167']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3167']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['3175']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3186']
# Canceled orders: ['3186']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3223']
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['3223']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['3233']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['3233']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3241']
# Canceled orders: ['3241']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3254']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3254']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['3260']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['3310']
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['3310']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3303', '3300', '3299']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['3345']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3345']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3364']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3364']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3369', '3367', '3366']
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['3369', '3367', '3366']
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3410']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3410']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['3432', '3429']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3432', '3429']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3456']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3456']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3456']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3465']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3465']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3465']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3492', '3486', '3489']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3492', '3486', '3489']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3492', '3486', '3489']
# Canceled orders: ['3492', '3486', '3489']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3515']
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['3515']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3543', '3540']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3543', '3540']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3543', '3540']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3547', '3546']
# Canceled orders: ['3547', '3546']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3552']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3552']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['3574']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3574']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['3586']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['3586']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3604']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3604']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3608']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3608']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3608']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3633', '3619', '3615', '3610']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3633', '3619', '3615', '3610']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3643']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3643']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3643']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3646']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3680', '3678']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3680', '3678']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3691']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3691']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3691']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3695']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3695']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3702']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3702']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3709']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3709']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3709']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3722']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3722']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3722']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3729']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3729']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3747']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3747']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3747']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3752']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3752']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3752']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3761']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['3791']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3791']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3804', '3797', '3793']
# Canceled orders: ['3804', '3797', '3793']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3848']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['3848']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['3848']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3856']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3856']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['3891']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3891']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3904', '3910']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3904', '3910']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3904', '3910']
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3923']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['3923']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3936']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3936']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3936']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['3950']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['3950']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['4005']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ...
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['7323']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7323']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7328']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7344', '7338', '7331']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7344', '7338', '7331']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['7354']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7354']
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7362']
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['7362']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7372']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['7382']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7382']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7421']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7421']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['7431']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7447']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7447']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7467']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7467']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7479']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7479']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7479']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7483']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7483']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7492']
# Canceled orders: ['7492']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7504']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7504']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7515']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7515']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['7515']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7520', '7518']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7526']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['7526']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['7526']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7532', '7531']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7532', '7531']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7533']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7533']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7533']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['7527']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7527']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7554', '7552']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7554', '7552']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['7575']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7575']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7581']
# Canceled orders: ['7581']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7581']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7584']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7584']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7601']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7601']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7606']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['7606']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['7606']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7610']
# Canceled orders: ['7610']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7625']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7625']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['7629']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['7629']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['7634']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['7638']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['7642']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['7653', '7652']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7653', '7652']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['7664']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['7672']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['7672']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7715']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7715']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7728']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7728']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7733']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7733']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7733']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7749']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['7749']
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['7785']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7785']
# Canceled orders: ['7785']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7785']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# ('Added limit order to ', 'SELL', ' ', 500, ' ', 'RITC')
# Canceled orders: ['7812', '7814']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7812', '7814']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 500, ' ', 'RITC')
# Canceled orders: ['7824']
# ('Added limit order to ', 'SELL', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7824']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7834']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7834']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# Canceled orders: ['7834']
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
# ('Added limit order to ', 'BUY', ' ', 1000, ' ', 'RITC')
